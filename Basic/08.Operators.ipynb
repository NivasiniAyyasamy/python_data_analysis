# %% [markdown]
# #Operators
#
# 1. Arithmetic Operators (+, - , *, /, %, **(Exponentiation), // (Floor Division) )
# 2. Assignment Operators ( =, +=, -=, *=, /=, %=, **=, //= )
# 3. Comparision Operator ( ==, !=, >, <, >=, <= )

# %%
min_sal = 20_000
max_sal = 80_000 # _ is ignored
avg_sal = (min_sal + max_sal) / 2
avg_sal
# Out:
# 50000.0

# %%
applicant_1 = 'Nivasini'
applicant_2 = 'Ayyasamy'

# %%
# To swap the values
# temp = applicant_2
# applicant_2 = applicant_1
# applicant_1 = temp

#But in python
applicant_1, applicant_2 = applicant_2, applicant_1
applicant_1, applicant_2
# Out:
# ('Ayyasamy', 'Nivasini')

# %% [markdown]
# ##Logical Operator
#
# * AND
# * OR
# * NOT

# %%
# AND - Every value should be true
# OR - Any one value should be true
# NOT - Opposite of the value

# %% [markdown]
# ## Membership Operators
#
# * IN - Membership
# * NOT IN - Not membership

# %%
# in and not in are case sensitie

# %% [markdown]
# ## Identity Operators
#
# This operatoe is used if an item corelates with an other item
# * IS
# * IS NOT
#
# Often these operators are confused with comparision operator(==)
# **IS** checks for the ariable uses the same memory location i.e., checks for the id(variable). Returns true only if the id is same for both the variables.

# %% [markdown]
# ## Bitwise Operator
#
# * & - Bitwise AND
# * | - Bitwise OR
# * ^ - Bitwise XOR
# * ~ - Bitwise NOT
# * << - Left shift
# * >> - Right shift
#
# This operator returns the bitwise value( how the computer reads the value ). This will be overriden when using pandas and matplotlib
