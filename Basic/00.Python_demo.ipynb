# %% [markdown]
# Getting started

# %%
2+2
# Out:
# 4

# %%
2+2
3*3
# Out:
# 9

# %%
print(2+2)
print(3*3)
# Out:
# 4
# 9

# %%
print(2+2)
3*3
# Out:
# 4
# 9

# %% [markdown]
# Make a Comment
# What if you wanted to include something in your code like a note?
#
# Include a # before the line
# This is called a comment
# That doesn't execute anything and isn't read by the Python interpreter when executing your code.

# %%
# This is a comment. Nothing to the right of the "#" sign will be interpreted

# %%
# This is a comment

print("What's Up, Data Nerds")
print(2 + 2) # This is a comment also
3 * 3
# Out:
# What's Up, Data Nerds
# 4
# 9

# %% [markdown]
# **Markdown Basics**
#
# Markdown is a lightweight markup language that uses characters like # for headings and * for emphasis to format text simply and intuitively.

# %% [markdown]
# | Element        | Markdown Syntax                        |
# |----------------|----------------------------------------|
# | Heading        | `# H1`<br>`## H2`<br>`### H3`          |
# | Bold           | `**bold text**`                        |
# | Italic         | `*italicized text*`                    |
# | Blockquote     | `> blockquote`                         |
# | Ordered List   | `1. First item`<br>`2. Second item`<br>`3. Third item` |
# | Unordered List | `- First item`<br>`- Second item`<br>`- Third item`   |
# | Code           | `` `code` ``                           |
# | Horizontal Rule| `---`                                  |
# | Link           | `[title](https://www.example.com)`     |
# | Image          | `![alt text](image.jpg)`               |
#
# [Here is a more info on Markdown](https://www.markdownguide.org/basic-syntax/)

# %% [markdown]
# Normal Text
#
# # Heading
#
# **bold**
#
# [Link](https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/1_Basics/01_Getting_Started.ipynb#scrollTo=OSsLjn-1hj3L)

# %% [markdown]
# ## Colab Walkthrough
#
# #### Sidebar Menu (Left-Top)
# - Table of Contents
# - Find and Replace
# - Variables
# - Secrets
# - Files
#
# #### Sidebar Menu (Left-Bottom)
# - Code snippets
# - Command pallette
# - Terminal
#
# #### Top Menu Bar
# - Runtime: Controls running cells and restarting notebook
#
# #### Colab Header (Top)
# - RAM & Disk Usage
# - Colab AI (may or may not have)

# %% [markdown]
# ### Runtime Deep Dive
#
# **Run All:**
# - ⚙️ Executes all notebook cells in sequence
#
# **Interrupt Execution:**
# - 🛑 Stops the execution of the current cell
#
# **Restart Session:**
# - 🔄 Resets the notebook's kernel, clearing all the executed code memory
# - ✨ No code execution afterward unless manually triggered
#
# **Disconnect and Delete Runtime:**
# - ❌ Stops the notebook, releases resources, and deletes any temporary files created during the session

# %% [markdown]
# ## Advanced Jupyter Notebook Usage
#
# Don't worry if you don't understand this right now as we'll cover more later.
#
# Just be aware that starting a line with any of the following symbols has magic properties.
#
# | Symbol | Name           | Example            | Usage Explanation                                                                 |
# |--------|----------------|--------------------|-----------------------------------------------------------------------------------|
# | `!`    | Shell Command  | `!ls`              | Executes shell commands directly from the notebook cell, such as listing files.   |
# | `%`    | Line Magic     | `%cd sample_data`     | Executes a line magic command, affecting only the line it is on, like changing directories. |
# | `%%`   | Cell Magic     | `%%writefile test.txt` | Applies the magic command to the entire cell, such as writing the cell's content to a file. |

# %%
# !ls
# Out:
# sample_data

# %%
# %timeit [i**2 for i in range(1000)] #For single line, this returns the time taken to execute
# Out:
# 69.5 µs ± 771 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %%timeit
L = []
for n in range(1000):
  L.append(n**2)
#For multiple lines of code this gives the time of execution
# Out:
# 78.6 µs ± 928 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# # Variable

# %% [markdown]
# variable_name = value

# %%
salary = 100000

# %%
salary
# Out:
# 100000

# %%
"salary"
# Out:
# 'salary'

# %% [markdown]
# ## Calculate the following

# %% [markdown]
# Total Salary = (Base salary) * (1 + Bonus Rate)

# %%
base_salary = 100000
bonus_rate = .10

# %%
total_salary = (base_salary) * (1 + bonus_rate)

# %%
total_salary
# Out:
# 110000.00000000001

# %%
lukes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1354324463.py in <cell line: 0>()
# ----> 1 lukes
#
# NameError: name 'lukes' is not defined

# %%
lukes salary
# Out:
#   File "/tmp/ipython-input-920562660.py", line 1
#     lukes salary
#           ^
# SyntaxError: invalid syntax

# %%
# Corrected code
lukes_salary

# %% [markdown]
# ## Variables aren't just numbers

# %% [markdown]
# Create variables to store the following information about a job posting
# 1. Job ID(Integer)
# 2. Company Name(String)
# 3. Salary Rate(string)
# 4. Job work from home(Boolean)

# %%
company_name = "Boehringer Ingelheim"

# %%
job_wfh = False

# %%
company_name
# Out:
# 'Boehringer Ingelheim'

# %%
job_id = 101
job_title = 'Data Analyst'
job_salary = 125000

# %%
print("Data Job Description")
print("Job ID:", job_id)
print("Company Name:", company_name)
print("Job Title:", job_title)
print("Salary:", job_salary)
print("Work from Home:", job_wfh)
#
# Out:
# Data Job Description
# Job ID: 101
# Company Name: Boehringer Ingelheim
# Job Title: Data Analyst
# Salary: 125000
# Work from Home: False

# %% [markdown]
# # Objects

# %% [markdown]
# Objects: Data Records
#
# Adata records with fields, an instance of a class

# %%
print (salary)
# Out:
# 100000

# %%
type(salary)
# Out:
# int

# %%
type(job_title)
# Out:
# str

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %% [markdown]
# ##Variables: The Refrence to Objects

# %% [markdown]
# Variable: A defined name that references an object

# %%
id(job_title)
# Out:
# 136217799925936

# %%
id(job_salary)
# Out:
# 136217797837168

# %%
job_1 = "Data Analyst"
job_2 = "Data Analyst"

# %%
id(job_1), id(job_2)
# Out:
# (136217801052592, 136217801057136)

# %%
job_3 = job_2

# %%
id(job_3), id(job_2)
# Out:
# (136217801057136, 136217801057136)

# %% [markdown]
# We can also assign a function to a variable

# %%
print("What's up?")
# Out:
# What's up?

# %%
my_print_func = print

# %%
my_print_func("Hey!")
# Out:
# Hey!

# %% [markdown]
# # Functions

# %% [markdown]
# Function: A reusable piece of code that performs a specific task.

# %%
print('Hey') #buildin function
# Out:
# Hey

# %%
def greet():
  return "Hey!" # Explicitely defining a function. def - define, greet - function name

# %%
greet()
# Out:
# 'Hey!'

# %%
def display_info(title, location, salary):
  return print(f"Job Title: {title}\nLocation: {location}\nSalary: {salary:,.0f}")

# %%
display_info(job_title, job_location, job_salary)
# Out:
# Job Title: Data Analyst
# Location: United States
# Salary: 100,000

# %%
job_title =  "Data Analyst"

# %%
job_salary = 100000
job_location = "United States"

# %% [markdown]
# # Classes

# %% [markdown]
# Class: A template for creating objects (records)

# %%
class JobPost:
  def __init__(self, title, location, salary):
    self.title = title
    self.location = location
    self.salary = salary

# %%
JobPost(job_title, job_location, job_salary)

# %% [markdown]
# #Attributes: The Varaibles of an Object

# %% [markdown]
# Attribute: A field in a record, defined by its class

# %%
job_1 = JobPost(job_title, job_location, job_salary)

# %%
print(job_1.location)
print(job_1.salary)
print(job_1.title) # These are Attributes
# Out:
# United States
# 100000
# Data Analyst

# %% [markdown]
# # Methods: The Functions of an object
#
# Method: A function defined inside a class that operates on ists objects

# %% [markdown]
# Function is outside the class. The same function inside a class is called Method.

# %% [markdown]
# #Datatypes
#
#
#
# 1.  int
# 2.  string
# 3.  Float
# 4.  Boolean

# %%
## Built-in Types
